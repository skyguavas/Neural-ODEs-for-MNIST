# %% [markdown]
# <a href="https://colab.research.google.com/github/skyguavas/Neural-ODEs-for-MNIST/blob/main/CS376_HW2_ODEnet_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# installer
# !pip install torchdiffeq
# Out:
# Collecting torchdiffeq
#   Downloading torchdiffeq-0.2.4-py3-none-any.whl (32 kB)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from torchdiffeq) (2.3.0+cu121)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from torchdiffeq) (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy>=1.4.0->torchdiffeq) (1.25.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (4.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.5.0->torchdiffeq)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 68.2 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.5.0->torchdiffeq) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.5.0->torchdiffeq) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchdiffeq
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 torchdiffeq-0.2.4

# %%
# importing necessary packages
import os
import argparse
import logging
import time
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# %%
# parser
# Importing ODE conditionally
parser = argparse.ArgumentParser()
parser.add_argument('--network', type=str, choices=['resnet', 'odenet'], default='odenet')
parser.add_argument('--tol', type=float, default=1e-3)
parser.add_argument('--adjoint', type=eval, default=True, choices=[True, False])
parser.add_argument('--downsampling-method', type=str, default='conv', choices=['conv', 'res'])
parser.add_argument('--nepochs', type=int, default=160)
parser.add_argument('--data_aug', type=eval, default=True, choices=[True, False])
parser.add_argument('--lr', type=float, default=0.1)
parser.add_argument('--batch_size', type=int, default=128)
parser.add_argument('--test_batch_size', type=int, default=1000)

parser.add_argument('--save', type=str, default='./experiment1')
parser.add_argument('--debug', action='store_true')
parser.add_argument('--gpu', type=int, default=0)
args = parser.parse_args(args=[])

if args.adjoint:
    from torchdiffeq import odeint_adjoint as odeint
else:
    from torchdiffeq import odeint

# %% [markdown]
# ### Used Adjoint as True
# ### And the solver as Euler

# %%
# model structure
def conv3x3(in_planes, out_planes, stride=1):
    """3x3 convolution with padding"""
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride, padding=1, bias=False)


def conv1x1(in_planes, out_planes, stride=1):
    """1x1 convolution"""
    return nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=stride, bias=False)


def norm(dim):
    return nn.GroupNorm(min(32, dim), dim)


class ResBlock(nn.Module):
    expansion = 1

    def __init__(self, inplanes, planes, stride=1, downsample=None):
        super(ResBlock, self).__init__()
        self.norm1 = norm(inplanes)
        self.relu = nn.ReLU(inplace=True)
        self.downsample = downsample
        self.conv1 = conv3x3(inplanes, planes, stride)
        self.norm2 = norm(planes)
        self.conv2 = conv3x3(planes, planes)

    def forward(self, x):
        shortcut = x

        out = self.relu(self.norm1(x))

        if self.downsample is not None:
            shortcut = self.downsample(out)

        out = self.conv1(out)
        out = self.norm2(out)
        out = self.relu(out)
        out = self.conv2(out)

        return out + shortcut


class ConcatConv2d(nn.Module):

    def __init__(self, dim_in, dim_out, ksize=3, stride=1, padding=0, dilation=1, groups=1, bias=True, transpose=False):
        super(ConcatConv2d, self).__init__()
        module = nn.ConvTranspose2d if transpose else nn.Conv2d
        self._layer = module(
            dim_in + 1, dim_out, kernel_size=ksize, stride=stride, padding=padding, dilation=dilation, groups=groups,
            bias=bias
        )

    def forward(self, t, x):
        tt = torch.ones_like(x[:, :1, :, :]) * t
        ttx = torch.cat([tt, x], 1)
        return self._layer(ttx)


class ODEfunc(nn.Module):

    def __init__(self, dim):
        super(ODEfunc, self).__init__()
        self.norm1 = norm(dim)
        self.relu = nn.ReLU(inplace=True)
        self.conv1 = ConcatConv2d(dim, dim, 3, 1, 1)
        self.norm2 = norm(dim)
        self.conv2 = ConcatConv2d(dim, dim, 3, 1, 1)
        self.norm3 = norm(dim)
        self.nfe = 0

    def forward(self, t, x):
        self.nfe += 1
        out = self.norm1(x)
        out = self.relu(out)
        out = self.conv1(t, out)
        out = self.norm2(out)
        out = self.relu(out)
        out = self.conv2(t, out)
        out = self.norm3(out)
        return out


class ODEBlock(nn.Module):

    def __init__(self, odefunc):
        super(ODEBlock, self).__init__()
        self.odefunc = odefunc
        self.integration_time = torch.tensor([0, 1]).float()

    def forward(self, x):
        self.integration_time = self.integration_time.type_as(x)
        out = odeint(self.odefunc, x, self.integration_time, rtol=args.tol, atol=args.tol, method='euler')
        return out[1]

    @property
    def nfe(self):
        return self.odefunc.nfe

    @nfe.setter
    def nfe(self, value):
        self.odefunc.nfe = value


class Flatten(nn.Module):

    def __init__(self):
        super(Flatten, self).__init__()

    def forward(self, x):
        shape = torch.prod(torch.tensor(x.shape[1:])).item()
        return x.view(-1, shape)


class RunningAverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self, momentum=0.99):
        self.momentum = momentum
        self.reset()

    def reset(self):
        self.val = None
        self.avg = 0

    def update(self, val):
        if self.val is None:
            self.avg = val
        else:
            self.avg = self.avg * self.momentum + val * (1 - self.momentum)
        self.val = val

# %%
# model structure
def get_mnist_loaders(data_aug=False, batch_size=128, test_batch_size=1000, perc=1.0):
    if data_aug:
        transform_train = transforms.Compose([
            transforms.RandomCrop(28, padding=4),
            transforms.ToTensor(),
        ])
    else:
        transform_train = transforms.Compose([
            transforms.ToTensor(),
        ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
    ])

    train_loader = DataLoader(
        datasets.MNIST(root='.data/mnist', train=True, download=True, transform=transform_train), batch_size=batch_size,
        shuffle=True, num_workers=2, drop_last=True
    )

    train_eval_loader = DataLoader(
        datasets.MNIST(root='.data/mnist', train=True, download=True, transform=transform_test),
        batch_size=test_batch_size, shuffle=False, num_workers=2, drop_last=True
    )

    test_loader = DataLoader(
        datasets.MNIST(root='.data/mnist', train=False, download=True, transform=transform_test),
        batch_size=test_batch_size, shuffle=False, num_workers=2, drop_last=True
    )

    return train_loader, test_loader, train_eval_loader


def inf_generator(iterable):
    """Allows training with DataLoaders in a single infinite loop:
        for i, (x, y) in enumerate(inf_generator(train_loader)):
    """
    iterator = iterable.__iter__()
    while True:
        try:
            yield iterator.__next__()
        except StopIteration:
            iterator = iterable.__iter__()


def learning_rate_with_decay(batch_size, batch_denom, batches_per_epoch, boundary_epochs, decay_rates):
    initial_learning_rate = args.lr * batch_size / batch_denom

    boundaries = [int(batches_per_epoch * epoch) for epoch in boundary_epochs]
    vals = [initial_learning_rate * decay for decay in decay_rates]

    def learning_rate_fn(itr):
        lt = [itr < b for b in boundaries] + [True]
        i = np.argmax(lt)
        return vals[i]

    return learning_rate_fn


def one_hot(x, K):
    return np.array(x[:, None] == np.arange(K)[None, :], dtype=int)


def accuracy(model, dataset_loader):
    total_correct = 0
    for x, y in dataset_loader:
        x = x.to(device)
        y = one_hot(np.array(y.numpy()), 10)

        target_class = np.argmax(y, axis=1)
        predicted_class = np.argmax(model(x).cpu().detach().numpy(), axis=1)
        total_correct += np.sum(predicted_class == target_class)
    return total_correct / len(dataset_loader.dataset)


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


def makedirs(dirname):
    if not os.path.exists(dirname):
        os.makedirs(dirname)


def get_logger(logpath, filepath, package_files=[], displaying=True, saving=True, debug=False):
    logger = logging.getLogger()
    if debug:
        level = logging.DEBUG
    else:
        level = logging.INFO
    logger.setLevel(level)
    if saving:
        info_file_handler = logging.FileHandler(logpath, mode="a")
        info_file_handler.setLevel(level)
        logger.addHandler(info_file_handler)
    if displaying:
        console_handler = logging.StreamHandler()
        console_handler.setLevel(level)
        logger.addHandler(console_handler)
    # logger.info(filepath)
    # might not be necessary to read this file since it is raising errors anyway
    # with open(filepath, "r") as f:
        # logger.info(f.read())

    # for f in package_files:
        # logger.info(f)
        # with open(f, "r") as package_f:
            # logger.info(package_f.read())

    return logger

# %%
# This is the main function used to run the entire colab notebook
if __name__ == '__main__':

    makedirs(args.save)
    logger = get_logger(logpath=os.path.join(args.save, 'logs'), filepath=os.path.abspath('')) # adjusted for .ipynb file
    logger.info(args)

    device = torch.device('cuda:' + str(args.gpu) if torch.cuda.is_available() else 'cpu')

    # In order to plot the graphs, the data needs to be stored
    epochs = []
    train_accs = []
    test_accs = []
    epoch_times = []

    is_odenet = args.network == 'odenet'

    if args.downsampling_method == 'conv':
        downsampling_layers = [
            nn.Conv2d(1, 64, 3, 1),
            norm(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 4, 2, 1),
            norm(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 4, 2, 1),
        ]
    elif args.downsampling_method == 'res':
        downsampling_layers = [
            nn.Conv2d(1, 64, 3, 1),
            ResBlock(64, 64, stride=2, downsample=conv1x1(64, 64, 2)),
            ResBlock(64, 64, stride=2, downsample=conv1x1(64, 64, 2)),
        ]

    feature_layers = [ODEBlock(ODEfunc(64))] if is_odenet else [ResBlock(64, 64) for _ in range(6)]
    fc_layers = [norm(64), nn.ReLU(inplace=True), nn.AdaptiveAvgPool2d((1, 1)), Flatten(), nn.Linear(64, 10)]

    model = nn.Sequential(*downsampling_layers, *feature_layers, *fc_layers).to(device)

    logger.info(model)
    logger.info('Number of parameters: {}'.format(count_parameters(model)))

    criterion = nn.CrossEntropyLoss().to(device)
    train_loader, test_loader, train_eval_loader = get_mnist_loaders(
        args.data_aug, args.batch_size, args.test_batch_size
    )

    data_gen = inf_generator(train_loader)
    batches_per_epoch = len(train_loader)

    lr_fn = learning_rate_with_decay(
        args.batch_size, batch_denom=128, batches_per_epoch=batches_per_epoch, boundary_epochs=[60, 100, 140],
        decay_rates=[1, 0.1, 0.01, 0.001]
    )

    optimizer = torch.optim.SGD(model.parameters(), lr=args.lr, momentum=0.9)

    best_acc = 0
    batch_time_meter = RunningAverageMeter()
    f_nfe_meter = RunningAverageMeter()
    b_nfe_meter = RunningAverageMeter()
    end = time.time()

    for epoch in range(args.nepochs):
        start_epoch_time = time.time()

        for itr in range(batches_per_epoch):
            for param_group in optimizer.param_groups:
                param_group['lr'] = lr_fn(itr)

            optimizer.zero_grad()
            x, y = data_gen.__next__()
            x = x.to(device)
            y = y.to(device)
            logits = model(x)
            loss = criterion(logits, y)

            if is_odenet:
                nfe_forward = feature_layers[0].nfe
                feature_layers[0].nfe = 0

            loss.backward()
            optimizer.step()

            if is_odenet:
                nfe_backward = feature_layers[0].nfe
                feature_layers[0].nfe = 0

            batch_time_meter.update(time.time() - end)
            if is_odenet:
                f_nfe_meter.update(nfe_forward)
                b_nfe_meter.update(nfe_backward)
            end = time.time()

        epoch_duration = time.time() - start_epoch_time
        epoch_times.append(epoch_duration)

        with torch.no_grad():
            train_acc = accuracy(model, train_eval_loader)
            val_acc = accuracy(model, test_loader)
            if val_acc > best_acc:
                torch.save({'state_dict': model.state_dict(), 'args': args}, os.path.join(args.save, 'model.pth'))
                best_acc = val_acc

        epochs.append(epoch)
        train_accs.append(train_acc)
        test_accs.append(val_acc)

        logger.info(
            f"Epoch {epoch:04d} | Time {epoch_duration:.3f} | Train Acc {train_acc:.4f} | Test Acc {val_acc:.4f} | NFE-F {f_nfe_meter.avg:.1f} | NFE-B {b_nfe_meter.avg:.1f}"
        )
# Out:
# INFO:root:Namespace(network='odenet', tol=0.001, adjoint=True, downsampling_method='conv', nepochs=160, data_aug=True, lr=0.1, batch_size=128, test_batch_size=1000, save='./experiment1', debug=False, gpu=0)
# Namespace(network='odenet', tol=0.001, adjoint=True, downsampling_method='conv', nepochs=160, data_aug=True, lr=0.1, batch_size=128, test_batch_size=1000, save='./experiment1', debug=False, gpu=0)
# INFO:root:Sequential(
#   (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1))
#   (1): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (2): ReLU(inplace=True)
#   (3): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (4): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (5): ReLU(inplace=True)
#   (6): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (7): ODEBlock(
#     (odefunc): ODEfunc(
#       (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (relu): ReLU(inplace=True)
#       (conv1): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (conv2): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm3): GroupNorm(32, 64, eps=1e-05, affine=True)
#     )
#   )
#   (8): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (9): ReLU(inplace=True)
#   (10): AdaptiveAvgPool2d(output_size=(1, 1))
#   (11): Flatten()
#   (12): Linear(in_features=64, out_features=10, bias=True)
# )
# Sequential(
#   (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1))
#   (1): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (2): ReLU(inplace=True)
#   (3): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (4): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (5): ReLU(inplace=True)
#   (6): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (7): ODEBlock(
#     (odefunc): ODEfunc(
#       (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (relu): ReLU(inplace=True)
#       (conv1): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (conv2): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm3): GroupNorm(32, 64, eps=1e-05, affine=True)
#     )
#   )
#   (8): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (9): ReLU(inplace=True)
#   (10): AdaptiveAvgPool2d(output_size=(1, 1))
#   (11): Flatten()
#   (12): Linear(in_features=64, out_features=10, bias=True)
# )
# INFO:root:Number of parameters: 208266
# Number of parameters: 208266
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to .data/mnist/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:02<00:00, 4592855.82it/s]
# Extracting .data/mnist/MNIST/raw/train-images-idx3-ubyte.gz to .data/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to .data/mnist/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 133441.98it/s]
# Extracting .data/mnist/MNIST/raw/train-labels-idx1-ubyte.gz to .data/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to .data/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:01<00:00, 1275075.35it/s]
# Extracting .data/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to .data/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to .data/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 4173171.69it/s]
# Extracting .data/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to .data/mnist/MNIST/raw
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a CuDNNError: cuDNN error: CUDNN_STATUS_BAD_PARAM
# Exception raised from run_conv_plan at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:374 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x57 (0x7a6740773897 in /usr/local/lib/python3.10/dist-packages/torch/lib/libc10.so)
# frame #1: <unknown function> + 0xe1c861 (0x7a66cd5f2861 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #2: <unknown function> + 0x1095d83 (0x7a66cd86bd83 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #3: <unknown function> + 0x1097c2c (0x7a66cd86dc2c in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #4: <unknown function> + 0x109832b (0x7a66cd86e32b in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #5: <unknown function> + 0x107c8bd (0x7a66cd8528bd in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #6: <unknown function> + 0x107e7d3 (0x7a66cd8547d3 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #7: at::native::convolution_backward(at::Tensor const&, at::Tensor const&, at::Tensor const&, c10::OptionalArrayRef<long>, c10::ArrayRef<long>, c10::ArrayRef<long>, c10::ArrayRef<long>, bool, c10::ArrayRef<long>, long, std::array<bool, 3ul>) + 0x27e0 (0x7a67022fc770 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #8: <unknown function> + 0x32e15f5 (0x7a66cfab75f5 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #9: <unknown function> + 0x32e96a2 (0x7a66cfabf6a2 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #10: at::_ops::convolution_backward::redispatch(c10::DispatchKeySet, at::Tensor const&, at::Tensor const&, at::Tensor const&, c10::OptionalArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, bool, c10::ArrayRef<c10::SymInt>, c10::SymInt, std::array<bool, 3ul>) + 0x26b (0x7a67031ca72b in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #11: <unknown function> + 0x48caf13 (0x7a6704f50f13 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #12: <unknown function> + 0x48ccac3 (0x7a6704f52ac3 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #13: at::_ops::convolution_backward::call(at::Tensor const&, at::Tensor const&, at::Tensor const&, c10::OptionalArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, bool, c10::ArrayRef<c10::SymInt>, c10::SymInt, std::array<bool, 3ul>) + 0x3a3 (0x7a67031f0de3 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #14: <unknown function> + 0x19bdad1 (0x7a6702043ad1 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #15: torch::autograd::generated::ConvolutionBackward0::apply(std::vector<at::Tensor, std::allocator<at::Tensor> >&&) + 0x300 (0x7a6704a628b0 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #16: <unknown function> + 0x513f9cb (0x7a67057c59cb in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #17: torch::autograd::Engine::evaluate_function(std::shared_ptr<torch::autograd::GraphTask>&, torch::autograd::Node*, torch::autograd::InputBuffer&, std::shared_ptr<torch::autograd::ReadyQueue> const&) + 0x1526 (0x7a67057bfac6 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #18: torch::autograd::Engine::thread_main(std::shared_ptr<torch::autograd::GraphTask> const&) + 0x698 (0x7a67057c0728 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #19: torch::autograd::Engine::thread_init(int, std::shared_ptr<torch::autograd::ReadyQueue> const&, bool) + 0x13f (0x7a67057b765f in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #20: torch::autograd::python::PythonEngine::thread_init(int, std::shared_ptr<torch::autograd::ReadyQueue> const&, bool) + 0x5c (0x7a671e123dac in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_python.so)
# frame #21: <unknown function> + 0xdc253 (0x7a6774636253 in /lib/x86_64-linux-gnu/libstdc++.so.6)
# frame #22: <unknown function> + 0x94ac3 (0x7a6776886ac3 in /lib/x86_64-linux-gnu/libc.so.6)
# frame #23: <unknown function> + 0x126850 (0x7a6776918850 in /lib/x86_64-linux-gnu/libc.so.6)
#  (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:921.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a CuDNNError: cuDNN error: CUDNN_STATUS_BAD_PARAM
# Exception raised from run_conv_plan at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:374 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x57 (0x7a6740773897 in /usr/local/lib/python3.10/dist-packages/torch/lib/libc10.so)
# frame #1: <unknown function> + 0xe1c861 (0x7a66cd5f2861 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #2: <unknown function> + 0x1095d83 (0x7a66cd86bd83 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #3: <unknown function> + 0x1097c2c (0x7a66cd86dc2c in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #4: <unknown function> + 0x10984d5 (0x7a66cd86e4d5 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #5: <unknown function> + 0x107dc64 (0x7a66cd853c64 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #6: <unknown function> + 0x107e670 (0x7a66cd854670 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #7: at::native::convolution_backward(at::Tensor const&, at::Tensor const&, at::Tensor const&, c10::OptionalArrayRef<long>, c10::ArrayRef<long>, c10::ArrayRef<long>, c10::ArrayRef<long>, bool, c10::ArrayRef<long>, long, std::array<bool, 3ul>) + 0x27e0 (0x7a67022fc770 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #8: <unknown function> + 0x32e15f5 (0x7a66cfab75f5 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #9: <unknown function> + 0x32e96a2 (0x7a66cfabf6a2 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #10: at::_ops::convolution_backward::redispatch(c10::DispatchKeySet, at::Tensor const&, at::Tensor const&, at::Tensor const&, c10::OptionalArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, bool, c10::ArrayRef<c10::SymInt>, c10::SymInt, std::array<bool, 3ul>) + 0x26b (0x7a67031ca72b in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #11: <unknown function> + 0x48caf13 (0x7a6704f50f13 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #12: <unknown function> + 0x48ccac3 (0x7a6704f52ac3 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #13: at::_ops::convolution_backward::call(at::Tensor const&, at::Tensor const&, at::Tensor const&, c10::OptionalArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, bool, c10::ArrayRef<c10::SymInt>, c10::SymInt, std::array<bool, 3ul>) + 0x3a3 (0x7a67031f0de3 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #14: <unknown function> + 0x19bdad1 (0x7a6702043ad1 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #15: torch::autograd::generated::ConvolutionBackward0::apply(std::vector<at::Tensor, std::allocator<at::Tensor> >&&) + 0x300 (0x7a6704a628b0 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #16: <unknown function> + 0x513f9cb (0x7a67057c59cb in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #17: torch::autograd::Engine::evaluate_function(std::shared_ptr<torch::autograd::GraphTask>&, torch::autograd::Node*, torch::autograd::InputBuffer&, std::shared_ptr<torch::autograd::ReadyQueue> const&) + 0x1526 (0x7a67057bfac6 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #18: torch::autograd::Engine::thread_main(std::shared_ptr<torch::autograd::GraphTask> const&) + 0x698 (0x7a67057c0728 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #19: torch::autograd::Engine::thread_init(int, std::shared_ptr<torch::autograd::ReadyQueue> const&, bool) + 0x13f (0x7a67057b765f in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #20: torch::autograd::python::PythonEngine::thread_init(int, std::shared_ptr<torch::autograd::ReadyQueue> const&, bool) + 0x5c (0x7a671e123dac in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch
| NFE-F 1.0 | NFE-B 1.0
# INFO:root:Epoch 0145 | Time 6.880 | Train Acc 0.9990 | Test Acc 0.9951 | NFE-F 1.0 | NFE-B 1.0
# Epoch 0145 | Time 6.880 | Train Acc 0.9990 | Test Acc 0.9951 | NFE-F 1.0 | NFE-B 1.0
# INFO:root:Epoch 0146 | Time 6.323 | Train Acc 0.9991 | Test Acc 0.9955 | NFE-F 1.0 | NFE-B 1.0
# Epoch 0146 | Time 6.323 | Train Acc 0.9991 | Test Acc 0.9955 | NFE-F 1.0 | NFE-B 1.0
# INFO:root:Epoch 0147 | Time 6.804 | Train Acc 0.9993 | Test Acc 0.9950 | NFE-F 1.0 | NFE-B 1.0
# Epoch 0147 | Time 6.804 | Train Acc 0.9993 | Test Acc 0.9950 | NFE-F 1.0 | NFE-B 1.0
# INFO:root:Epoch 0148 | Time 6.455 | Train Acc 0.9985 | Test Acc 0.9943 | NFE-F 1.0 | NFE-B 1.0
# Epoch 0148 | Time 6.455 | Train Acc 0.9985 | Test Acc 0.9943 | NFE-F 1.0 | NFE-B 1.0
# INFO:root:Epoch 0149 | Time 6.670 | Train Acc 0.9980 | Test Acc 0.9955 | NFE-F 1.0 | NFE-B 1.0
# Epoch 0149 | Time 6.670 | Train Acc 0.9980 | Test Acc 0.9955 | NFE-F 1.0 | NFE-B 1.0
# INFO:root:Epoch 0150 | Time 6.572 | Train Acc 0.9991 | Test Acc 0.9952 | NFE-F 1.0 | NFE-B 1.0
# Epoch 0150 | Time 6.572 | Train Acc 0.9991 | Test Acc 0.9952 | NFE-F 1.0 | NFE-B 1.0
# INFO:root:Epoch 0151 | Time 6.485 | Train Acc 0.9990 | Test Acc 0.9955 | NFE-F 1.0 | NFE-B 1.0
# Epoch 0151 | Time 6.485 | Train Acc 0.9990 | Test Acc 0.9955 | NFE-F 1.0 | NFE-B 1.0
# INFO:root:Epoch 0152 | Time 6.937 | Train Acc 0.9990 | Test Acc 0.9947 | NFE-F 1.0 | NFE-B 1.0
# Epoch 0152 | Time 6.937 | Train Acc 0.9990 | Test Acc 0.9947 | NFE-F 1.0 | NFE-B 1.0
# INFO:root:Epoch 0153 | Time 6.463 | Train Acc 0.9987 | Test Acc 0.9940 | NFE-F 1.0 | NFE-B 1.0
# Epoch 0153 | Time 6.463 | Train Acc 0.9987 | Test Acc 0.9940 | NFE-F 1.0 | NFE-B 1.0
# INFO:root:Epoch 0154 | Time 6.673 | Train Acc 0.9993 | Test Acc 0.9946 | NFE-F 1.0 | NFE-B 1.0
# Epoch 0154 | Time 6.673 | Train Acc 0.9993 | Test Acc 0.9946 | NFE-F 1.0 | NFE-B 1.0
# INFO:root:Epoch 0155 | Time 6.924 | Train Acc 0.9992 | Test Acc 0.9946 | NFE-F 1.0 | NFE-B 1.0
# Epoch 0155 | Time 6.924 | Train Acc 0.9992 | Test Acc 0.9946 | NFE-F 1.0 | NFE-B 1.0
# INFO:root:Epoch 0156 | Time 6.547 | Train Acc 0.9987 | Test Acc 0.9945 | NFE-F 1.0 | NFE-B 1.0
# Epoch 0156 | Time 6.547 | Train Acc 0.9987 | Test Acc 0.9945 | NFE-F 1.0 | NFE-B 1.0
# INFO:root:Epoch 0157 | Time 6.612 | Train Acc 0.9987 | Test Acc 0.9942 | NFE-F 1.0 | NFE-B 1.0
# Epoch 0157 | Time 6.612 | Train Acc 0.9987 | Test Acc 0.9942 | NFE-F 1.0 | NFE-B 1.0
# INFO:root:Epoch 0158 | Time 6.447 | Train Acc 0.9980 | Test Acc 0.9931 | NFE-F 1.0 | NFE-B 1.0
# Epoch 0158 | Time 6.447 | Train Acc 0.9980 | Test Acc 0.9931 | NFE-F 1.0 | NFE-B 1.0
# INFO:root:Epoch 0159 | Time 6.590 | Train Acc 0.9991 | Test Acc 0.9945 | NFE-F 1.0 | NFE-B 1.0
# Epoch 0159 | Time 6.590 | Train Acc 0.9991 | Test Acc 0.9945 | NFE-F 1.0 | NFE-B 1.0

# %%
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_accs, label='Train Accuracy')
plt.plot(epochs, test_accs, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Epoch vs Accuracy')
plt.legend()
plt.grid(True)
plt.show()

average_epoch_time = sum(epoch_times) / len(epoch_times)
print(f"Average Wall-Clock Time per Epoch: {average_epoch_time:.3f} seconds")
# Out:
# Average Wall-Clock Time per Epoch: 6.621 seconds

# %% [markdown]
# ## Adjoint = True, RK4

# %%
# model structure
def conv3x3(in_planes, out_planes, stride=1):
    """3x3 convolution with padding"""
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride, padding=1, bias=False)


def conv1x1(in_planes, out_planes, stride=1):
    """1x1 convolution"""
    return nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=stride, bias=False)


def norm(dim):
    return nn.GroupNorm(min(32, dim), dim)


class ResBlock(nn.Module):
    expansion = 1

    def __init__(self, inplanes, planes, stride=1, downsample=None):
        super(ResBlock, self).__init__()
        self.norm1 = norm(inplanes)
        self.relu = nn.ReLU(inplace=True)
        self.downsample = downsample
        self.conv1 = conv3x3(inplanes, planes, stride)
        self.norm2 = norm(planes)
        self.conv2 = conv3x3(planes, planes)

    def forward(self, x):
        shortcut = x

        out = self.relu(self.norm1(x))

        if self.downsample is not None:
            shortcut = self.downsample(out)

        out = self.conv1(out)
        out = self.norm2(out)
        out = self.relu(out)
        out = self.conv2(out)

        return out + shortcut


class ConcatConv2d(nn.Module):

    def __init__(self, dim_in, dim_out, ksize=3, stride=1, padding=0, dilation=1, groups=1, bias=True, transpose=False):
        super(ConcatConv2d, self).__init__()
        module = nn.ConvTranspose2d if transpose else nn.Conv2d
        self._layer = module(
            dim_in + 1, dim_out, kernel_size=ksize, stride=stride, padding=padding, dilation=dilation, groups=groups,
            bias=bias
        )

    def forward(self, t, x):
        tt = torch.ones_like(x[:, :1, :, :]) * t
        ttx = torch.cat([tt, x], 1)
        return self._layer(ttx)


class ODEfunc(nn.Module):

    def __init__(self, dim):
        super(ODEfunc, self).__init__()
        self.norm1 = norm(dim)
        self.relu = nn.ReLU(inplace=True)
        self.conv1 = ConcatConv2d(dim, dim, 3, 1, 1)
        self.norm2 = norm(dim)
        self.conv2 = ConcatConv2d(dim, dim, 3, 1, 1)
        self.norm3 = norm(dim)
        self.nfe = 0

    def forward(self, t, x):
        self.nfe += 1
        out = self.norm1(x)
        out = self.relu(out)
        out = self.conv1(t, out)
        out = self.norm2(out)
        out = self.relu(out)
        out = self.conv2(t, out)
        out = self.norm3(out)
        return out


class ODEBlock(nn.Module):

    def __init__(self, odefunc):
        super(ODEBlock, self).__init__()
        self.odefunc = odefunc
        self.integration_time = torch.tensor([0, 1]).float()

    def forward(self, x):
        self.integration_time = self.integration_time.type_as(x)
        out = odeint(self.odefunc, x, self.integration_time, rtol=args.tol, atol=args.tol, method='rk4')
        return out[1]

    @property
    def nfe(self):
        return self.odefunc.nfe

    @nfe.setter
    def nfe(self, value):
        self.odefunc.nfe = value


class Flatten(nn.Module):

    def __init__(self):
        super(Flatten, self).__init__()

    def forward(self, x):
        shape = torch.prod(torch.tensor(x.shape[1:])).item()
        return x.view(-1, shape)


class RunningAverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self, momentum=0.99):
        self.momentum = momentum
        self.reset()

    def reset(self):
        self.val = None
        self.avg = 0

    def update(self, val):
        if self.val is None:
            self.avg = val
        else:
            self.avg = self.avg * self.momentum + val * (1 - self.momentum)
        self.val = val

# %%
# model structure
def get_mnist_loaders(data_aug=False, batch_size=128, test_batch_size=1000, perc=1.0):
    if data_aug:
        transform_train = transforms.Compose([
            transforms.RandomCrop(28, padding=4),
            transforms.ToTensor(),
        ])
    else:
        transform_train = transforms.Compose([
            transforms.ToTensor(),
        ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
    ])

    train_loader = DataLoader(
        datasets.MNIST(root='.data/mnist', train=True, download=True, transform=transform_train), batch_size=batch_size,
        shuffle=True, num_workers=2, drop_last=True
    )

    train_eval_loader = DataLoader(
        datasets.MNIST(root='.data/mnist', train=True, download=True, transform=transform_test),
        batch_size=test_batch_size, shuffle=False, num_workers=2, drop_last=True
    )

    test_loader = DataLoader(
        datasets.MNIST(root='.data/mnist', train=False, download=True, transform=transform_test),
        batch_size=test_batch_size, shuffle=False, num_workers=2, drop_last=True
    )

    return train_loader, test_loader, train_eval_loader


def inf_generator(iterable):
    """Allows training with DataLoaders in a single infinite loop:
        for i, (x, y) in enumerate(inf_generator(train_loader)):
    """
    iterator = iterable.__iter__()
    while True:
        try:
            yield iterator.__next__()
        except StopIteration:
            iterator = iterable.__iter__()


def learning_rate_with_decay(batch_size, batch_denom, batches_per_epoch, boundary_epochs, decay_rates):
    initial_learning_rate = args.lr * batch_size / batch_denom

    boundaries = [int(batches_per_epoch * epoch) for epoch in boundary_epochs]
    vals = [initial_learning_rate * decay for decay in decay_rates]

    def learning_rate_fn(itr):
        lt = [itr < b for b in boundaries] + [True]
        i = np.argmax(lt)
        return vals[i]

    return learning_rate_fn


def one_hot(x, K):
    return np.array(x[:, None] == np.arange(K)[None, :], dtype=int)


def accuracy(model, dataset_loader):
    total_correct = 0
    for x, y in dataset_loader:
        x = x.to(device)
        y = one_hot(np.array(y.numpy()), 10)

        target_class = np.argmax(y, axis=1)
        predicted_class = np.argmax(model(x).cpu().detach().numpy(), axis=1)
        total_correct += np.sum(predicted_class == target_class)
    return total_correct / len(dataset_loader.dataset)


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


def makedirs(dirname):
    if not os.path.exists(dirname):
        os.makedirs(dirname)


def get_logger(logpath, filepath, package_files=[], displaying=True, saving=True, debug=False):
    logger = logging.getLogger()
    if debug:
        level = logging.DEBUG
    else:
        level = logging.INFO
    logger.setLevel(level)
    if saving:
        info_file_handler = logging.FileHandler(logpath, mode="a")
        info_file_handler.setLevel(level)
        logger.addHandler(info_file_handler)
    if displaying:
        console_handler = logging.StreamHandler()
        console_handler.setLevel(level)
        logger.addHandler(console_handler)
    # logger.info(filepath)
    # might not be necessary to read this file since it is raising errors anyway
    # with open(filepath, "r") as f:
        # logger.info(f.read())

    # for f in package_files:
        # logger.info(f)
        # with open(f, "r") as package_f:
            # logger.info(package_f.read())

    return logger

# %%
# This is the main function used to run the entire colab notebook
if __name__ == '__main__':

    makedirs(args.save)
    logger = get_logger(logpath=os.path.join(args.save, 'logs'), filepath=os.path.abspath('')) # adjusted for .ipynb file
    logger.info(args)

    device = torch.device('cuda:' + str(args.gpu) if torch.cuda.is_available() else 'cpu')

    # In order to plot the graphs, the data needs to be stored
    epochs = []
    train_accs = []
    test_accs = []
    epoch_times = []

    is_odenet = args.network == 'odenet'

    if args.downsampling_method == 'conv':
        downsampling_layers = [
            nn.Conv2d(1, 64, 3, 1),
            norm(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 4, 2, 1),
            norm(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 4, 2, 1),
        ]
    elif args.downsampling_method == 'res':
        downsampling_layers = [
            nn.Conv2d(1, 64, 3, 1),
            ResBlock(64, 64, stride=2, downsample=conv1x1(64, 64, 2)),
            ResBlock(64, 64, stride=2, downsample=conv1x1(64, 64, 2)),
        ]

    feature_layers = [ODEBlock(ODEfunc(64))] if is_odenet else [ResBlock(64, 64) for _ in range(6)]
    fc_layers = [norm(64), nn.ReLU(inplace=True), nn.AdaptiveAvgPool2d((1, 1)), Flatten(), nn.Linear(64, 10)]

    model = nn.Sequential(*downsampling_layers, *feature_layers, *fc_layers).to(device)

    logger.info(model)
    logger.info('Number of parameters: {}'.format(count_parameters(model)))

    criterion = nn.CrossEntropyLoss().to(device)
    train_loader, test_loader, train_eval_loader = get_mnist_loaders(
        args.data_aug, args.batch_size, args.test_batch_size
    )

    data_gen = inf_generator(train_loader)
    batches_per_epoch = len(train_loader)

    lr_fn = learning_rate_with_decay(
        args.batch_size, batch_denom=128, batches_per_epoch=batches_per_epoch, boundary_epochs=[60, 100, 140],
        decay_rates=[1, 0.1, 0.01, 0.001]
    )

    optimizer = torch.optim.SGD(model.parameters(), lr=args.lr, momentum=0.9)

    best_acc = 0
    batch_time_meter = RunningAverageMeter()
    f_nfe_meter = RunningAverageMeter()
    b_nfe_meter = RunningAverageMeter()
    end = time.time()

    for epoch in range(args.nepochs):
        start_epoch_time = time.time()

        for itr in range(batches_per_epoch):
            for param_group in optimizer.param_groups:
                param_group['lr'] = lr_fn(itr)

            optimizer.zero_grad()
            x, y = data_gen.__next__()
            x = x.to(device)
            y = y.to(device)
            logits = model(x)
            loss = criterion(logits, y)

            if is_odenet:
                nfe_forward = feature_layers[0].nfe
                feature_layers[0].nfe = 0

            loss.backward()
            optimizer.step()

            if is_odenet:
                nfe_backward = feature_layers[0].nfe
                feature_layers[0].nfe = 0

            batch_time_meter.update(time.time() - end)
            if is_odenet:
                f_nfe_meter.update(nfe_forward)
                b_nfe_meter.update(nfe_backward)
            end = time.time()

        epoch_duration = time.time() - start_epoch_time
        epoch_times.append(epoch_duration)

        with torch.no_grad():
            train_acc = accuracy(model, train_eval_loader)
            val_acc = accuracy(model, test_loader)
            if val_acc > best_acc:
                torch.save({'state_dict': model.state_dict(), 'args': args}, os.path.join(args.save, 'model.pth'))
                best_acc = val_acc

        epochs.append(epoch)
        train_accs.append(train_acc)
        test_accs.append(val_acc)

        logger.info(
            f"Epoch {epoch:04d} | Time {epoch_duration:.3f} | Train Acc {train_acc:.4f} | Test Acc {val_acc:.4f} | NFE-F {f_nfe_meter.avg:.1f} | NFE-B {b_nfe_meter.avg:.1f}"
        )
# Out:
# INFO:root:Namespace(network='odenet', tol=0.001, adjoint=True, downsampling_method='conv', nepochs=160, data_aug=True, lr=0.1, batch_size=128, test_batch_size=1000, save='./experiment1', debug=False, gpu=0)
# Namespace(network='odenet', tol=0.001, adjoint=True, downsampling_method='conv', nepochs=160, data_aug=True, lr=0.1, batch_size=128, test_batch_size=1000, save='./experiment1', debug=False, gpu=0)
# INFO:root:Sequential(
#   (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1))
#   (1): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (2): ReLU(inplace=True)
#   (3): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (4): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (5): ReLU(inplace=True)
#   (6): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (7): ODEBlock(
#     (odefunc): ODEfunc(
#       (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (relu): ReLU(inplace=True)
#       (conv1): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (conv2): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm3): GroupNorm(32, 64, eps=1e-05, affine=True)
#     )
#   )
#   (8): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (9): ReLU(inplace=True)
#   (10): AdaptiveAvgPool2d(output_size=(1, 1))
#   (11): Flatten()
#   (12): Linear(in_features=64, out_features=10, bias=True)
# )
# Sequential(
#   (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1))
#   (1): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (2): ReLU(inplace=True)
#   (3): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (4): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (5): ReLU(inplace=True)
#   (6): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (7): ODEBlock(
#     (odefunc): ODEfunc(
#       (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (relu): ReLU(inplace=True)
#       (conv1): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (conv2): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm3): GroupNorm(32, 64, eps=1e-05, affine=True)
#     )
#   )
#   (8): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (9): ReLU(inplace=True)
#   (10): AdaptiveAvgPool2d(output_size=(1, 1))
#   (11): Flatten()
#   (12): Linear(in_features=64, out_features=10, bias=True)
# )
# INFO:root:Number of parameters: 208266
# Number of parameters: 208266
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to .data/mnist/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:02<00:00, 4663233.51it/s]
# Extracting .data/mnist/MNIST/raw/train-images-idx3-ubyte.gz to .data/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to .data/mnist/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 134592.22it/s]
# Extracting .data/mnist/MNIST/raw/train-labels-idx1-ubyte.gz to .data/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to .data/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:01<00:00, 1270526.30it/s]
# Extracting .data/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to .data/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to .data/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 4709648.64it/s]
# Extracting .data/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to .data/mnist/MNIST/raw
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a CuDNNError: cuDNN error: CUDNN_STATUS_BAD_PARAM
# Exception raised from run_conv_plan at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:374 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x57 (0x7ee770279897 in /usr/local/lib/python3.10/dist-packages/torch/lib/libc10.so)
# frame #1: <unknown function> + 0xe1c861 (0x7ee7036ed861 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #2: <unknown function> + 0x1095d83 (0x7ee703966d83 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #3: <unknown function> + 0x1097c2c (0x7ee703968c2c in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #4: <unknown function> + 0x109832b (0x7ee70396932b in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #5: <unknown function> + 0x107c8bd (0x7ee70394d8bd in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #6: <unknown function> + 0x107e7d3 (0x7ee70394f7d3 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #7: at::native::convolution_backward(at::Tensor const&, at::Tensor const&, at::Tensor const&, c10::OptionalArrayRef<long>, c10::ArrayRef<long>, c10::ArrayRef<long>, c10::ArrayRef<long>, bool, c10::ArrayRef<long>, long, std::array<bool, 3ul>) + 0x27e0 (0x7ee7383f7770 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #8: <unknown function> + 0x32e15f5 (0x7ee705bb25f5 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #9: <unknown function> + 0x32e96a2 (0x7ee705bba6a2 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #10: at::_ops::convolution_backward::redispatch(c10::DispatchKeySet, at::Tensor const&, at::Tensor const&, at::Tensor const&, c10::OptionalArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, bool, c10::ArrayRef<c10::SymInt>, c10::SymInt, std::array<bool, 3ul>) + 0x26b (0x7ee7392c572b in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #11: <unknown function> + 0x48caf13 (0x7ee73b04bf13 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #12: <unknown function> + 0x48ccac3 (0x7ee73b04dac3 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #13: at::_ops::convolution_backward::call(at::Tensor const&, at::Tensor const&, at::Tensor const&, c10::OptionalArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, bool, c10::ArrayRef<c10::SymInt>, c10::SymInt, std::array<bool, 3ul>) + 0x3a3 (0x7ee7392ebde3 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #14: <unknown function> + 0x19bdad1 (0x7ee73813ead1 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #15: torch::autograd::generated::ConvolutionBackward0::apply(std::vector<at::Tensor, std::allocator<at::Tensor> >&&) + 0x300 (0x7ee73ab5d8b0 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #16: <unknown function> + 0x513f9cb (0x7ee73b8c09cb in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #17: torch::autograd::Engine::evaluate_function(std::shared_ptr<torch::autograd::GraphTask>&, torch::autograd::Node*, torch::autograd::InputBuffer&, std::shared_ptr<torch::autograd::ReadyQueue> const&) + 0x1526 (0x7ee73b8baac6 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #18: torch::autograd::Engine::thread_main(std::shared_ptr<torch::autograd::GraphTask> const&) + 0x698 (0x7ee73b8bb728 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #19: torch::autograd::Engine::thread_init(int, std::shared_ptr<torch::autograd::ReadyQueue> const&, bool) + 0x13f (0x7ee73b8b265f in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #20: torch::autograd::python::PythonEngine::thread_init(int, std::shared_ptr<torch::autograd::ReadyQueue> const&, bool) + 0x5c (0x7ee74e923dac in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_python.so)
# frame #21: <unknown function> + 0xdc253 (0x7ee7a8b50253 in /lib/x86_64-linux-gnu/libstdc++.so.6)
# frame #22: <unknown function> + 0x94ac3 (0x7ee7aada0ac3 in /lib/x86_64-linux-gnu/libc.so.6)
# frame #23: <unknown function> + 0x126850 (0x7ee7aae32850 in /lib/x86_64-linux-gnu/libc.so.6)
#  (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:921.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a CuDNNError: cuDNN error: CUDNN_STATUS_BAD_PARAM
# Exception raised from run_conv_plan at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:374 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x57 (0x7ee770279897 in /usr/local/lib/python3.10/dist-packages/torch/lib/libc10.so)
# frame #1: <unknown function> + 0xe1c861 (0x7ee7036ed861 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #2: <unknown function> + 0x1095d83 (0x7ee703966d83 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #3: <unknown function> + 0x1097c2c (0x7ee703968c2c in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #4: <unknown function> + 0x10984d5 (0x7ee7039694d5 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #5: <unknown function> + 0x107dc64 (0x7ee70394ec64 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #6: <unknown function> + 0x107e670 (0x7ee70394f670 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #7: at::native::convolution_backward(at::Tensor const&, at::Tensor const&, at::Tensor const&, c10::OptionalArrayRef<long>, c10::ArrayRef<long>, c10::ArrayRef<long>, c10::ArrayRef<long>, bool, c10::ArrayRef<long>, long, std::array<bool, 3ul>) + 0x27e0 (0x7ee7383f7770 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #8: <unknown function> + 0x32e15f5 (0x7ee705bb25f5 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #9: <unknown function> + 0x32e96a2 (0x7ee705bba6a2 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cuda.so)
# frame #10: at::_ops::convolution_backward::redispatch(c10::DispatchKeySet, at::Tensor const&, at::Tensor const&, at::Tensor const&, c10::OptionalArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, bool, c10::ArrayRef<c10::SymInt>, c10::SymInt, std::array<bool, 3ul>) + 0x26b (0x7ee7392c572b in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #11: <unknown function> + 0x48caf13 (0x7ee73b04bf13 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #12: <unknown function> + 0x48ccac3 (0x7ee73b04dac3 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #13: at::_ops::convolution_backward::call(at::Tensor const&, at::Tensor const&, at::Tensor const&, c10::OptionalArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, c10::ArrayRef<c10::SymInt>, bool, c10::ArrayRef<c10::SymInt>, c10::SymInt, std::array<bool, 3ul>) + 0x3a3 (0x7ee7392ebde3 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #14: <unknown function> + 0x19bdad1 (0x7ee73813ead1 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #15: torch::autograd::generated::ConvolutionBackward0::apply(std::vector<at::Tensor, std::allocator<at::Tensor> >&&) + 0x300 (0x7ee73ab5d8b0 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #16: <unknown function> + 0x513f9cb (0x7ee73b8c09cb in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #17: torch::autograd::Engine::evaluate_function(std::shared_ptr<torch::autograd::GraphTask>&, torch::autograd::Node*, torch::autograd::InputBuffer&, std::shared_ptr<torch::autograd::ReadyQueue> const&) + 0x1526 (0x7ee73b8baac6 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #18: torch::autograd::Engine::thread_main(std::shared_ptr<torch::autograd::GraphTask> const&) + 0x698 (0x7ee73b8bb728 in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #19: torch::autograd::Engine::thread_init(int, std::shared_ptr<torch::autograd::ReadyQueue> const&, bool) + 0x13f (0x7ee73b8b265f in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_cpu.so)
# frame #20: torch::autograd::python::PythonEngine::thread_init(int, std::shared_ptr<torch::autograd::ReadyQueue> const&, bool) + 0x5c (0x7ee74e923dac in /usr/local/lib/python3.10/dist-packages/torch/lib/libtorch_python.so)
# frame #21: <unknown function> + 0xdc253 (0x7ee7a8b50253 in /lib/x86_64-linux-gnu/libstdc++.so.6)
# frame #22: <unknown function> + 0x94ac3 (0x7ee7aada0ac3 in /lib/x86_64-linux-gnu/libc.so.6)
# frame #23: <unknown function> + 0x126850 (0x7ee7aae32850 in /lib/x86_64-linux-gnu/libc.so.6)
#  (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:921.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# INFO:root:Epoch 0000 | Time 11.057 | Train Acc 0.9660 | Test Acc 0.9679 | NFE-F 4.0 | NFE-B 4.0
# Epoch 0000 | Time 11.057 | Train Acc 0.9660 | Test Acc 0.9679 | NFE-F 4.0 | NFE-B 4.0
# INFO:root:Epoch 0001 | Time 8.866 | Train Acc 0.9862 | Test Acc 0.9882 | NFE-F 4.0 | NFE-B 4.0
# Epoch 0001 | Time 8.866 | Train Acc 0.9862 | Test Acc 0.9882 | NFE-F 4.0 | NFE-B 4.0
# INFO:root:Epoch 0002 | Time 9.100 | Train Acc 0.9877 | Test Acc 0.9902 | NFE-F 4.0 | NFE-B 4.0
# Epoch 0002 | Time 9.100 | Train Acc 0.9877 | Test Acc 0.9902 | NFE-F 4.0 | NFE-B 4.0
# INFO:root:Epoch 0003 | Time 8.995 | Train Acc 0.9902 | Test Acc 0.9895 | NFE-F 4.0 | NFE-B 4.0
# Epoch 0003 | Time 8.995 | Train Acc 0.9902 | Test Acc 0.9895 | NFE-F 4.0 | NFE-B 4.0
# INFO:root:Epoch 0004 | Time 8.908 | Train Acc 0.9912 | Test Acc 0.9919 | NFE-F 4.0 | NFE-B 4.0
# Epoch 0004 | Time 8.908 | Train Acc 0.9912 | Test Acc 0.9919 | NFE-F 4.0 | NFE-B 4.0
# INFO:root:Epoch 0005 | Time 8.537 | Train Acc 0.9933 | Test Acc 0.9927 | NFE-F 4.0 | NFE-B 4.0
# Epoch 0005 | Time 8.537 | Train Acc 0.9933 | Test Acc 0.9927 | NFE-F 4.0 | NFE-B 4.0
# INFO:root:Epoch 0006 | Time 8.697 | Train Acc 0.9919 | Test Acc 0.9906 | NFE-F 4.0 | NFE-B 4.0
# Epoch 0006 | Time 8.697 | Train Acc 0.9919 | Test Acc 0.9906 | NFE-F 4.0 | NFE-B 4.0
# INFO:root:Epoch 0007 | Time 8.485 | Train Acc 0.9946 | Test Acc 0.9933 | NFE-F 4.0 | NFE-B 4.0
# Epoch 0007 | Time 8.485 | Train Acc 0.9946 | Test Acc 0.9933 | NFE-F 4.0 | NFE-B 4.0
# INFO:root:Epoch 0008 | Time 8.579 | Train Acc 0.9936 | Test Acc 0.9923 | NFE-F 4.0 | NFE-B 4.0
# Epoch 0008 | Time 8.579 | Train Acc 0.9936 | Test Acc 0.9923 | NFE-F 4.0 | NFE-B 4.0
# INFO:root:Epoch 0009 | Time 8.740 | Train Acc 0.9951 | Test Acc 0.9944 | NFE-F 4.0 | NFE-B 4.0
# Epoch 0009 | Time 8.740 | Train Acc 0.9951 | Test Acc 0.9944 | NFE-F 4.0 | NFE-B 4.0
# INFO:root:Epoch 0010 | Time 9.268 | Train Acc 0.9930 | Test Acc 0.9929 | NFE-F 4.0 | NFE-B 4.0
# Epoch 0010 | Time 9.268 | Train Acc 0.9930 | Test Acc 0.9929 | NFE-F 4.0 | NFE-B 4.0
# INFO:root:Epoch 0011 | Time 9.099 | Train Acc 0.9967 | Test Acc 0.9949 | NFE-F 4.0 | NFE-B 4.0
# Epoch 
label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Epoch vs Accuracy')
plt.legend()
plt.grid(True)
plt.show()

average_epoch_time = sum(epoch_times) / len(epoch_times)
print(f"Average Wall-Clock Time per Epoch: {average_epoch_time:.3f} seconds")
# Out:
# Average Wall-Clock Time per Epoch: 8.924 seconds

# %% [markdown]
# ## Adjoint = True, DOPRI

# %%
# model structure
def conv3x3(in_planes, out_planes, stride=1):
    """3x3 convolution with padding"""
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride, padding=1, bias=False)


def conv1x1(in_planes, out_planes, stride=1):
    """1x1 convolution"""
    return nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=stride, bias=False)


def norm(dim):
    return nn.GroupNorm(min(32, dim), dim)


class ResBlock(nn.Module):
    expansion = 1

    def __init__(self, inplanes, planes, stride=1, downsample=None):
        super(ResBlock, self).__init__()
        self.norm1 = norm(inplanes)
        self.relu = nn.ReLU(inplace=True)
        self.downsample = downsample
        self.conv1 = conv3x3(inplanes, planes, stride)
        self.norm2 = norm(planes)
        self.conv2 = conv3x3(planes, planes)

    def forward(self, x):
        shortcut = x

        out = self.relu(self.norm1(x))

        if self.downsample is not None:
            shortcut = self.downsample(out)

        out = self.conv1(out)
        out = self.norm2(out)
        out = self.relu(out)
        out = self.conv2(out)

        return out + shortcut


class ConcatConv2d(nn.Module):

    def __init__(self, dim_in, dim_out, ksize=3, stride=1, padding=0, dilation=1, groups=1, bias=True, transpose=False):
        super(ConcatConv2d, self).__init__()
        module = nn.ConvTranspose2d if transpose else nn.Conv2d
        self._layer = module(
            dim_in + 1, dim_out, kernel_size=ksize, stride=stride, padding=padding, dilation=dilation, groups=groups,
            bias=bias
        )

    def forward(self, t, x):
        tt = torch.ones_like(x[:, :1, :, :]) * t
        ttx = torch.cat([tt, x], 1)
        return self._layer(ttx)


class ODEfunc(nn.Module):

    def __init__(self, dim):
        super(ODEfunc, self).__init__()
        self.norm1 = norm(dim)
        self.relu = nn.ReLU(inplace=True)
        self.conv1 = ConcatConv2d(dim, dim, 3, 1, 1)
        self.norm2 = norm(dim)
        self.conv2 = ConcatConv2d(dim, dim, 3, 1, 1)
        self.norm3 = norm(dim)
        self.nfe = 0

    def forward(self, t, x):
        self.nfe += 1
        out = self.norm1(x)
        out = self.relu(out)
        out = self.conv1(t, out)
        out = self.norm2(out)
        out = self.relu(out)
        out = self.conv2(t, out)
        out = self.norm3(out)
        return out


class ODEBlock(nn.Module):

    def __init__(self, odefunc):
        super(ODEBlock, self).__init__()
        self.odefunc = odefunc
        self.integration_time = torch.tensor([0, 1]).float()

    def forward(self, x):
        self.integration_time = self.integration_time.type_as(x)
        out = odeint(self.odefunc, x, self.integration_time, rtol=args.tol, atol=args.tol, method='dopri5')
        return out[1]

    @property
    def nfe(self):
        return self.odefunc.nfe

    @nfe.setter
    def nfe(self, value):
        self.odefunc.nfe = value


class Flatten(nn.Module):

    def __init__(self):
        super(Flatten, self).__init__()

    def forward(self, x):
        shape = torch.prod(torch.tensor(x.shape[1:])).item()
        return x.view(-1, shape)


class RunningAverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self, momentum=0.99):
        self.momentum = momentum
        self.reset()

    def reset(self):
        self.val = None
        self.avg = 0

    def update(self, val):
        if self.val is None:
            self.avg = val
        else:
            self.avg = self.avg * self.momentum + val * (1 - self.momentum)
        self.val = val

# %%
# model structure
def get_mnist_loaders(data_aug=False, batch_size=128, test_batch_size=1000, perc=1.0):
    if data_aug:
        transform_train = transforms.Compose([
            transforms.RandomCrop(28, padding=4),
            transforms.ToTensor(),
        ])
    else:
        transform_train = transforms.Compose([
            transforms.ToTensor(),
        ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
    ])

    train_loader = DataLoader(
        datasets.MNIST(root='.data/mnist', train=True, download=True, transform=transform_train), batch_size=batch_size,
        shuffle=True, num_workers=2, drop_last=True
    )

    train_eval_loader = DataLoader(
        datasets.MNIST(root='.data/mnist', train=True, download=True, transform=transform_test),
        batch_size=test_batch_size, shuffle=False, num_workers=2, drop_last=True
    )

    test_loader = DataLoader(
        datasets.MNIST(root='.data/mnist', train=False, download=True, transform=transform_test),
        batch_size=test_batch_size, shuffle=False, num_workers=2, drop_last=True
    )

    return train_loader, test_loader, train_eval_loader


def inf_generator(iterable):
    """Allows training with DataLoaders in a single infinite loop:
        for i, (x, y) in enumerate(inf_generator(train_loader)):
    """
    iterator = iterable.__iter__()
    while True:
        try:
            yield iterator.__next__()
        except StopIteration:
            iterator = iterable.__iter__()


def learning_rate_with_decay(batch_size, batch_denom, batches_per_epoch, boundary_epochs, decay_rates):
    initial_learning_rate = args.lr * batch_size / batch_denom

    boundaries = [int(batches_per_epoch * epoch) for epoch in boundary_epochs]
    vals = [initial_learning_rate * decay for decay in decay_rates]

    def learning_rate_fn(itr):
        lt = [itr < b for b in boundaries] + [True]
        i = np.argmax(lt)
        return vals[i]

    return learning_rate_fn


def one_hot(x, K):
    return np.array(x[:, None] == np.arange(K)[None, :], dtype=int)


def accuracy(model, dataset_loader):
    total_correct = 0
    for x, y in dataset_loader:
        x = x.to(device)
        y = one_hot(np.array(y.numpy()), 10)

        target_class = np.argmax(y, axis=1)
        predicted_class = np.argmax(model(x).cpu().detach().numpy(), axis=1)
        total_correct += np.sum(predicted_class == target_class)
    return total_correct / len(dataset_loader.dataset)


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


def makedirs(dirname):
    if not os.path.exists(dirname):
        os.makedirs(dirname)


def get_logger(logpath, filepath, package_files=[], displaying=True, saving=True, debug=False):
    logger = logging.getLogger()
    if debug:
        level = logging.DEBUG
    else:
        level = logging.INFO
    logger.setLevel(level)
    if saving:
        info_file_handler = logging.FileHandler(logpath, mode="a")
        info_file_handler.setLevel(level)
        logger.addHandler(info_file_handler)
    if displaying:
        console_handler = logging.StreamHandler()
        console_handler.setLevel(level)
        logger.addHandler(console_handler)
    # logger.info(filepath)
    # might not be necessary to read this file since it is raising errors anyway
    # with open(filepath, "r") as f:
        # logger.info(f.read())

    # for f in package_files:
        # logger.info(f)
        # with open(f, "r") as package_f:
            # logger.info(package_f.read())

    return logger

# %%
# This is the main function used to run the entire colab notebook
if __name__ == '__main__':

    makedirs(args.save)
    logger = get_logger(logpath=os.path.join(args.save, 'logs'), filepath=os.path.abspath('')) # adjusted for .ipynb file
    logger.info(args)

    device = torch.device('cuda:' + str(args.gpu) if torch.cuda.is_available() else 'cpu')

    # In order to plot the graphs, the data needs to be stored
    epochs = []
    train_accs = []
    test_accs = []
    epoch_times = []

    is_odenet = args.network == 'odenet'

    if args.downsampling_method == 'conv':
        downsampling_layers = [
            nn.Conv2d(1, 64, 3, 1),
            norm(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 4, 2, 1),
            norm(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 4, 2, 1),
        ]
    elif args.downsampling_method == 'res':
        downsampling_layers = [
            nn.Conv2d(1, 64, 3, 1),
            ResBlock(64, 64, stride=2, downsample=conv1x1(64, 64, 2)),
            ResBlock(64, 64, stride=2, downsample=conv1x1(64, 64, 2)),
        ]

    feature_layers = [ODEBlock(ODEfunc(64))] if is_odenet else [ResBlock(64, 64) for _ in range(6)]
    fc_layers = [norm(64), nn.ReLU(inplace=True), nn.AdaptiveAvgPool2d((1, 1)), Flatten(), nn.Linear(64, 10)]

    model = nn.Sequential(*downsampling_layers, *feature_layers, *fc_layers).to(device)

    logger.info(model)
    logger.info('Number of parameters: {}'.format(count_parameters(model)))

    criterion = nn.CrossEntropyLoss().to(device)
    train_loader, test_loader, train_eval_loader = get_mnist_loaders(
        args.data_aug, args.batch_size, args.test_batch_size
    )

    data_gen = inf_generator(train_loader)
    batches_per_epoch = len(train_loader)

    lr_fn = learning_rate_with_decay(
        args.batch_size, batch_denom=128, batches_per_epoch=batches_per_epoch, boundary_epochs=[60, 100, 140],
        decay_rates=[1, 0.1, 0.01, 0.001]
    )

    optimizer = torch.optim.SGD(model.parameters(), lr=args.lr, momentum=0.9)

    best_acc = 0
    batch_time_meter = RunningAverageMeter()
    f_nfe_meter = RunningAverageMeter()
    b_nfe_meter = RunningAverageMeter()
    end = time.time()

    for epoch in range(args.nepochs):
        start_epoch_time = time.time()

        for itr in range(batches_per_epoch):
            for param_group in optimizer.param_groups:
                param_group['lr'] = lr_fn(itr)

            optimizer.zero_grad()
            x, y = data_gen.__next__()
            x = x.to(device)
            y = y.to(device)
            logits = model(x)
            loss = criterion(logits, y)

            if is_odenet:
                nfe_forward = feature_layers[0].nfe
                feature_layers[0].nfe = 0

            loss.backward()
            optimizer.step()

            if is_odenet:
                nfe_backward = feature_layers[0].nfe
                feature_layers[0].nfe = 0

            batch_time_meter.update(time.time() - end)
            if is_odenet:
                f_nfe_meter.update(nfe_forward)
                b_nfe_meter.update(nfe_backward)
            end = time.time()

        epoch_duration = time.time() - start_epoch_time
        epoch_times.append(epoch_duration)

        with torch.no_grad():
            train_acc = accuracy(model, train_eval_loader)
            val_acc = accuracy(model, test_loader)
            if val_acc > best_acc:
                torch.save({'state_dict': model.state_dict(), 'args': args}, os.path.join(args.save, 'model.pth'))
                best_acc = val_acc

        epochs.append(epoch)
        train_accs.append(train_acc)
        test_accs.append(val_acc)

        logger.info(
            f"Epoch {epoch:04d} | Time {epoch_duration:.3f} | Train Acc {train_acc:.4f} | Test Acc {val_acc:.4f} | NFE-F {f_nfe_meter.avg:.1f} | NFE-B {b_nfe_meter.avg:.1f}"
        )
# Out:
# INFO:root:Namespace(network='odenet', tol=0.001, adjoint=True, downsampling_method='conv', nepochs=160, data_aug=True, lr=0.1, batch_size=128, test_batch_size=1000, save='./experiment1', debug=False, gpu=0)
# Namespace(network='odenet', tol=0.001, adjoint=True, downsampling_method='conv', nepochs=160, data_aug=True, lr=0.1, batch_size=128, test_batch_size=1000, save='./experiment1', debug=False, gpu=0)
# Namespace(network='odenet', tol=0.001, adjoint=True, downsampling_method='conv', nepochs=160, data_aug=True, lr=0.1, batch_size=128, test_batch_size=1000, save='./experiment1', debug=False, gpu=0)
# INFO:root:Sequential(
#   (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1))
#   (1): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (2): ReLU(inplace=True)
#   (3): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (4): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (5): ReLU(inplace=True)
#   (6): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (7): ODEBlock(
#     (odefunc): ODEfunc(
#       (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (relu): ReLU(inplace=True)
#       (conv1): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (conv2): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm3): GroupNorm(32, 64, eps=1e-05, affine=True)
#     )
#   )
#   (8): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (9): ReLU(inplace=True)
#   (10): AdaptiveAvgPool2d(output_size=(1, 1))
#   (11): Flatten()
#   (12): Linear(in_features=64, out_features=10, bias=True)
# )
# Sequential(
#   (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1))
#   (1): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (2): ReLU(inplace=True)
#   (3): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (4): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (5): ReLU(inplace=True)
#   (6): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (7): ODEBlock(
#     (odefunc): ODEfunc(
#       (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (relu): ReLU(inplace=True)
#       (conv1): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (conv2): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm3): GroupNorm(32, 64, eps=1e-05, affine=True)
#     )
#   )
#   (8): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (9): ReLU(inplace=True)
#   (10): AdaptiveAvgPool2d(output_size=(1, 1))
#   (11): Flatten()
#   (12): Linear(in_features=64, out_features=10, bias=True)
# )
# Sequential(
#   (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1))
#   (1): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (2): ReLU(inplace=True)
#   (3): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (4): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (5): ReLU(inplace=True)
#   (6): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (7): ODEBlock(
#     (odefunc): ODEfunc(
#       (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (relu): ReLU(inplace=True)
#       (conv1): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (conv2): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm3): GroupNorm(32, 64, eps=1e-05, affine=True)
#     )
#   )
#   (8): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (9): ReLU(inplace=True)
#   (10): AdaptiveAvgPool2d(output_size=(1, 1))
#   (11): Flatten()
#   (12): Linear(in_features=64, out_features=10, bias=True)
# )
# INFO:root:Number of parameters: 208266
# Number of parameters: 208266
# Number of parameters: 208266
# INFO:root:Epoch 0000 | Time 42.769 | Train Acc 0.9783 | Test Acc 0.9791 | NFE-F 20.1 | NFE-B 20.9
# Epoch 0000 | Time 42.769 | Train Acc 0.9783 | Test Acc 0.9791 | NFE-F 20.1 | NFE-B 20.9
# Epoch 0000 | Time 42.769 | Train Acc 0.9783 | Test Acc 0.9791 | NFE-F 20.1 | NFE-B 20.9
# INFO:root:Epoch 0001 | Time 42.026 | Train Acc 0.9873 | Test Acc 0.9880 | NFE-F 20.1 | NFE-B 20.2
# Epoch 0001 | Time 42.026 | Train Acc 0.9873 | Test Acc 0.9880 | NFE-F 20.1 | NFE-B 20.2
# Epoch 0001 | Time 42.026 | Train Acc 0.9873 | Test Acc 0.9880 | NFE-F 20.1 | NFE-B 20.2
# INFO:root:Epoch 0002 | Time 41.807 | Train Acc 0.9905 | Test Acc 0.9902 | NFE-F 20.1 | NFE-B 20.0
# Epoch 0002 | Time 41.807 | Train Acc 0.9905 | Test Acc 0.9902 | NFE-F 20.1 | NFE-B 20.0
# Epoch 0002 | Time 41.807 | Train Acc 0.9905 | Test Acc 0.9902 | NFE-F 20.1 | NFE-B 20.0
# INFO:root:Epoch 0003 | Time 41.774 | Train Acc 0.9929 | Test Acc 0.9926 | NFE-F 20.2 | NFE-B 20.0
# Epoch 0003 | Time 41.774 | Train Acc 0.9929 | Test Acc 0.9926 | NFE-F 20.2 | NFE-B 20.0
# Epoch 0003 | Time 41.774 | Train Acc 0.9929 | Test Acc 0.9926 | NFE-F 20.2 | NFE-B 20.0
# INFO:root:Epoch 0004 | Time 41.973 | Train Acc 0.9934 | Test Acc 0.9922 | NFE-F 20.2 | NFE-B 20.0
# Epoch 0004 | Time 41.973 | Train Acc 0.9934 | Test Acc 0.9922 | NFE-F 20.2 | NFE-B 20.0
# Epoch 0004 | Time 41.973 | Train Acc 0.9934 | Test Acc 0.9922 | NFE-F 20.2 | NFE-B 20.0
# INFO:root:Epoch 0005 | Time 41.754 | Train Acc 0.9916 | Test Acc 0.9910 | NFE-F 20.4 | NFE-B 20.0
# Epoch 0005 | Time 41.754 | Train Acc 0.9916 | Test Acc 0.9910 | NFE-F 20.4 | NFE-B 20.0
# Epoch 0005 | Time 41.754 | Train Acc 0.9916 | Test Acc 0.9910 | NFE-F 20.4 | NFE-B 20.0
# INFO:root:Epoch 0006 | Time 41.751 | Train Acc 0.9943 | Test Acc 0.9924 | NFE-F 20.2 | NFE-B 20.0
# Epoch 0006 | Time 41.751 | Train Acc 0.9943 | Test Acc 0.9924 | NFE-F 20.2 | NFE-B 20.0
# Epoch 0006 | Time 41.751 | Train Acc 0.9943 | Test Acc 0.9924 | NFE-F 20.2 | NFE-B 20.0
# INFO:root:Epoch 0007 | Time 42.348 | Train Acc 0.9931 | Test Acc 0.9916 | NFE-F 21.3 | NFE-B 20.1
# Epoch 0007 | Time 42.348 | Train Acc 0.9931 | Test Acc 0.9916 | NFE-F 21.3 | NFE-B 20.1
# Epoch 0007 | Time 42.348 | Train Acc 0.9931 | Test Acc 0.9916 | NFE-F 21.3 | NFE-B 20.1
# INFO:root:Epoch 0008 | Time 41.923 | Train Acc 0.9947 | Test Acc 0.9941 | NFE-F 20.2 | NFE-B 20.0
# Epoch 0008 | Time 41.923 | Train Acc 0.9947 | Test Acc 0.9941 | NFE-F 20.2 | NFE-B 20.0
# Epoch 0008 | Time 41.923 | Train Acc 0.9947 | Test Acc 0.9941 | NFE-F 20.2 | NFE-B 20.0
# INFO:root:Epoch 0009 | Time 42.326 | Train Acc 0.9952 | Test Acc 0.9933 | NFE-F 20.8 | NFE-B 20.0
# Epoch 0009 | Time 42.326 | Train Acc 0.9952 | Test Acc 0.9933 | NFE-F 20.8 | NFE-B 20.0
# Epoch 0009 | Time 42.326 | Train Acc 0.9952 | Test Acc 0.9933 | NFE-F 20.8 | NFE-B 20.0
# INFO:root:Epoch 0010 | Time 42.356 | Train Acc 0.9962 | Test Acc 0.9933 | NFE-F 21.9 | NFE-B 20.0
# Epoch 0010 | Time 42.356 | Train Acc 0.9962 | Test Acc 0.9933 | NFE-F 21.9 | NFE-B 20.0
# Epoch 0010 | Time 42.356 | Train Acc 0.9962 | Test Acc 0.9933 | NFE-F 21.9 | NFE-B 20.0
# INFO:root:Epoch 0011 | Time 43.792 | Train Acc 0.9966 | Test Acc 0.9928 | NFE-F 24.0 | NFE-B 20.0
# Epoch 0011 | Time 43.792 | Train Acc 0.9966 | Test Acc 0.9928 | NFE-F 24.0 | NFE-B 20.0
# Epoch 0011 | Time 43.792 | Train Acc 0.9966 | Test Acc 0.9928 | NFE-F 24.0 | NFE-B 20.0
# INFO:root:Epoch 0012 | Time 43.854 | Train Acc 0.9966 | Test Acc 0.9939 | NFE-F 24.5 | NFE-B 20.0
# Epoch 0012 | Time 43.854 | Train Acc 0.9966 | Test Acc 0.9939 | NFE-F 24.5 | NFE-B 20.0
# Epoch 0012 | Time 43.854 | Train Acc 0.9966 | Test Acc 0.9939 | NFE-F 24.5 | NFE-B 20.0
# INFO:root:Epoch 0013 | Time 45.016 | Train Acc 0.9959 | Test Acc 0.9928 | NFE-F 25.6 | NFE-B 20.0
# Epoch 0013 | Time 45.016 | Train Acc 0.9959 | Test Acc 0.9928 | NFE-F 25.6 | NFE-B 20.0
# Epoch 0013 | Time 45.016 | Train Acc 0.9959 | Test Acc 0.9928 | NFE-F 25.6 | NFE-B 20.0
# INFO:root:Epoch 0014 | Time 44.513 | Train Acc 0.9935 | Test Acc 0.9899 | NFE-F 25.0 | NFE-B 20.0
# Epoch 0014 | Time 44.513 | Train Acc 0.9935 | Test Acc 0.9899 | NFE-F 25.0 | NFE-B 20.0
# Epoch 0014 | Time 44.513 | Train Acc 0.9935 | Test Acc 0.9899 | NFE-F 25.0 | NFE-B 20.0
# INFO:root:Epoch 0015 | Time 45.018 | Train Acc 0.9970 | Test Acc 0.9952 | NFE-F 25.4 | NFE-B 20.0
# Epoch 0015 | Time 45.018 | Train Acc 0.9970 | Test Acc 0.9952 | NFE-F 25.4 | NFE-B 20.0
# Epoch 0015 | Time 45.018 | Train Acc 0.9970 | Test Acc 0.9952 | NFE-F 25.4 | NFE-B 20.0
# INFO:root:Epoch 0016 | Time 45.151 | Train Acc 0.9970 | Test Acc 0.9953 | NFE-F 25.6 | NFE-B 20.0
# Epoch 0016 | Time 45.151 | Train Acc 0.9970 | Test Acc 0.9953 | NFE-F 25.6 | NFE-B 20.0
# Epoch 0016 | Time 45.151 | Train Acc 0.9970 | Test Acc 0.9953 | NFE-F 25.6 | NFE-B 20.0
# INFO:root:Epoch 0017 | Time 45.492 | Train Acc 0.9980 | Test Acc 0.9948 | NFE-F 25.4 | NFE-B 20.0
# Epoch 0017 | Time 45.492 | Train Acc 0.9980 | Test Acc 0.9948 | NFE-F 25.4 | NFE-B 20.0
# Epoch 0017 | Time 45.492 | Train Acc 0.9980 | Test Acc 0.9948 | NFE-F 25.4 | NFE-B 20.0
# INFO:root:Epoch 0018 | Time 45.670 | Train Acc 0.9980 | Test Acc 0.9957 | NFE-F 26.0 | NFE-B 20.0
# Epoch 0018 | Time 45.670 | Train Acc 0.9980 | Test Acc 0.9957 | NFE-F 26.0 | NFE-B 20.0
# Epoch 0018 | Time 45.670 | Train Acc 0.9980 | Test Acc 0.9957 | NFE-F 26.0 | NFE-B 20.0
# INFO:root:Epoch 0019 | Time 45.525 | Train Acc 0.9978 | Test Acc 0.9949 | NFE-F 26.1 | NFE-B 20.0
# Epoch 0019 | Time 45.525 | Train Acc 0.9978 | Test Acc 0.9949 | NFE-F 26.1 | NFE-B 20.0
# Epoch 0019 | Time 45.525 | Train Acc 0.9978 | Test Acc 0.9949 | NFE-F 26.1 | NFE-B 20.0
# INFO:root:Epoch 0020 | Time 45.368 | Train Acc 0.9984 | Test Acc 0.9951 | NFE-F 25.9 | NFE-B 20.0
# Epoch 0020 | Time 45.368 | Train Acc 0.9984 | Test Acc 0.9951 | NFE-F 25.9 | NFE-B 20.0
# Epoch 0020 | Time 45.368 | Train Acc 0.9984 | Test Acc 0.9951 | NFE-F 25.9 | NFE-B 20.0
# INFO:root:Epoch 0021 | Time 45.479 | Train Acc 0.9974 | Test Acc 0.9947 | NFE-F 26.2 | NFE-B 20.0
# Epoch 0021 | Time 45.479 | Train Acc 0.9974 | Test Acc 0.9947 | NFE-F 26.2 | NFE-B 20.0
# Epoch 0021 | Time 45.479 | Train Acc 0.9974 | Test Acc 0.9947 | NFE-F 26.2 | NFE-B 20.0
# INFO:root:Epoch 0022 | Time 45.466 | Train Acc 0.9957 | Test Acc 0.9923 | NFE-F 26.0 | NFE-B 20.0
# Epoch 0022 | Time 45.466 | Train Acc 0.9957 | Test Acc 0.9923 | NFE-F 26.0 | NFE-B 20.0
# Epoch 0022 | Time 45.466 | Train Acc 0.9957 | Test Acc 0.9923 | NFE-F 26.0 | NFE-B 20.0
# INFO:root:Epoch 0023 | Time 45.278 | Train Acc 0.9980 | Test Acc 0.9956 | NFE-F 26.2 | NFE-B 20.0
# Epoch 0023 | Time 45.278 | Train Acc 0.9980 | Test Acc 0.9956 | NFE-F 26.2 | NFE-B 20.0
# Epoch 0023 | Time 45.278 | Train Acc 0.9980 | Test Acc 0.9956 | NFE-F 26.2 | NFE-B 20.0
# INFO:root:Epoch 0024 | Time 45.586 | Train Acc 0.9984 | Test Acc 0.9951 | NFE-F 26.2 | NFE-B 20.0
# Epoch 0024 | Time 45.586 | Train Acc 0.9984 | Test Acc 0.9951 | NFE-F 26.2 | NFE-B 20.0
# Epoch 0024 | Time 45.586 | Train Acc 0.9984 | Test Acc 0.9951 | NFE-F 26.2 | NFE-B 20.0
# INFO:root:Epoch 0025 | Time 45.467 | Train Acc 0.9980 | Test Acc 0.9933 | NFE-F 26.1 | NFE-B 20.0
# Epoch 0025 | Time 45.467 | Train Acc 0.9980 | Test Acc 0.9933 | NFE-F 26.1 | NFE-B 20.0
# Epoch 0025 | Time 45.467 | Train Acc 0.9980 | Test Acc 0.9933 | NFE-F 26.1 | NFE-B 20.0
# INFO:root:Epoch 0026 | Time 45.142 | Train Acc 0.9973 | Test Acc 0.9942 | NFE-F 26.1 | NFE-B 20.0
# Epoch 0026 | Time 45.142 | Train Acc 0.9973 | Test Acc 0.9942 | NFE-F 26.1 | NFE-B 20.0
# Epoch 0026 | Time 45.142 | Train Acc 0.9973 | Test Acc 0.9942 | NFE-F 26.1 | NFE-B 20.0
# INFO:root:Epoch 0027 | Time 45.549 | Train Acc 0.9976 | Test Acc 0.9939 | NFE-F 26.2 | NFE-B 20.0
# Epoch 
| Train Acc 0.9999 | Test Acc 0.9956 | NFE-F 26.2 | NFE-B 20.0

# %%
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_accs, label='Train Accuracy')
plt.plot(epochs, test_accs, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Epoch vs Accuracy')
plt.legend()
plt.grid(True)
plt.show()

average_epoch_time = sum(epoch_times) / len(epoch_times)
print(f"Average Wall-Clock Time per Epoch: {average_epoch_time:.3f} seconds")
# Out:
# Average Wall-Clock Time per Epoch: 45.219 seconds

# %% [markdown]
# ## Adjoint = False

# %%
# parser and conditional import of ode
parser = argparse.ArgumentParser()
parser.add_argument('--network', type=str, choices=['resnet', 'odenet'], default='odenet')
parser.add_argument('--tol', type=float, default=1e-3)
parser.add_argument('--adjoint', type=eval, default=False, choices=[True, False])
parser.add_argument('--downsampling-method', type=str, default='conv', choices=['conv', 'res'])
parser.add_argument('--nepochs', type=int, default=160)
parser.add_argument('--data_aug', type=eval, default=True, choices=[True, False])
parser.add_argument('--lr', type=float, default=0.1)
parser.add_argument('--batch_size', type=int, default=128)
parser.add_argument('--test_batch_size', type=int, default=1000)

parser.add_argument('--save', type=str, default='./experiment1')
parser.add_argument('--debug', action='store_true')
parser.add_argument('--gpu', type=int, default=0)
args = parser.parse_args(args=[]) # modified to make this runnable

if args.adjoint:
    from torchdiffeq import odeint_adjoint as odeint
else:
    from torchdiffeq import odeint

# %%
# model structure
def conv3x3(in_planes, out_planes, stride=1):
    """3x3 convolution with padding"""
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride, padding=1, bias=False)


def conv1x1(in_planes, out_planes, stride=1):
    """1x1 convolution"""
    return nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=stride, bias=False)


def norm(dim):
    return nn.GroupNorm(min(32, dim), dim)


class ResBlock(nn.Module):
    expansion = 1

    def __init__(self, inplanes, planes, stride=1, downsample=None):
        super(ResBlock, self).__init__()
        self.norm1 = norm(inplanes)
        self.relu = nn.ReLU(inplace=True)
        self.downsample = downsample
        self.conv1 = conv3x3(inplanes, planes, stride)
        self.norm2 = norm(planes)
        self.conv2 = conv3x3(planes, planes)

    def forward(self, x):
        shortcut = x

        out = self.relu(self.norm1(x))

        if self.downsample is not None:
            shortcut = self.downsample(out)

        out = self.conv1(out)
        out = self.norm2(out)
        out = self.relu(out)
        out = self.conv2(out)

        return out + shortcut


class ConcatConv2d(nn.Module):

    def __init__(self, dim_in, dim_out, ksize=3, stride=1, padding=0, dilation=1, groups=1, bias=True, transpose=False):
        super(ConcatConv2d, self).__init__()
        module = nn.ConvTranspose2d if transpose else nn.Conv2d
        self._layer = module(
            dim_in + 1, dim_out, kernel_size=ksize, stride=stride, padding=padding, dilation=dilation, groups=groups,
            bias=bias
        )

    def forward(self, t, x):
        tt = torch.ones_like(x[:, :1, :, :]) * t
        ttx = torch.cat([tt, x], 1)
        return self._layer(ttx)


class ODEfunc(nn.Module):

    def __init__(self, dim):
        super(ODEfunc, self).__init__()
        self.norm1 = norm(dim)
        self.relu = nn.ReLU(inplace=True)
        self.conv1 = ConcatConv2d(dim, dim, 3, 1, 1)
        self.norm2 = norm(dim)
        self.conv2 = ConcatConv2d(dim, dim, 3, 1, 1)
        self.norm3 = norm(dim)
        self.nfe = 0

    def forward(self, t, x):
        self.nfe += 1
        out = self.norm1(x)
        out = self.relu(out)
        out = self.conv1(t, out)
        out = self.norm2(out)
        out = self.relu(out)
        out = self.conv2(t, out)
        out = self.norm3(out)
        return out


class ODEBlock(nn.Module):

    def __init__(self, odefunc):
        super(ODEBlock, self).__init__()
        self.odefunc = odefunc
        self.integration_time = torch.tensor([0, 1]).float()

    def forward(self, x):
        self.integration_time = self.integration_time.type_as(x)
        out = odeint(self.odefunc, x, self.integration_time, rtol=args.tol, atol=args.tol)
        return out[1]

    @property
    def nfe(self):
        return self.odefunc.nfe

    @nfe.setter
    def nfe(self, value):
        self.odefunc.nfe = value


class Flatten(nn.Module):

    def __init__(self):
        super(Flatten, self).__init__()

    def forward(self, x):
        shape = torch.prod(torch.tensor(x.shape[1:])).item()
        return x.view(-1, shape)


class RunningAverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self, momentum=0.99):
        self.momentum = momentum
        self.reset()

    def reset(self):
        self.val = None
        self.avg = 0

    def update(self, val):
        if self.val is None:
            self.avg = val
        else:
            self.avg = self.avg * self.momentum + val * (1 - self.momentum)
        self.val = val

# %%
# model structure
def get_mnist_loaders(data_aug=False, batch_size=128, test_batch_size=1000, perc=1.0):
    if data_aug:
        transform_train = transforms.Compose([
            transforms.RandomCrop(28, padding=4),
            transforms.ToTensor(),
        ])
    else:
        transform_train = transforms.Compose([
            transforms.ToTensor(),
        ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
    ])

    train_loader = DataLoader(
        datasets.MNIST(root='.data/mnist', train=True, download=True, transform=transform_train), batch_size=batch_size,
        shuffle=True, num_workers=2, drop_last=True
    )

    train_eval_loader = DataLoader(
        datasets.MNIST(root='.data/mnist', train=True, download=True, transform=transform_test),
        batch_size=test_batch_size, shuffle=False, num_workers=2, drop_last=True
    )

    test_loader = DataLoader(
        datasets.MNIST(root='.data/mnist', train=False, download=True, transform=transform_test),
        batch_size=test_batch_size, shuffle=False, num_workers=2, drop_last=True
    )

    return train_loader, test_loader, train_eval_loader


def inf_generator(iterable):
    """Allows training with DataLoaders in a single infinite loop:
        for i, (x, y) in enumerate(inf_generator(train_loader)):
    """
    iterator = iterable.__iter__()
    while True:
        try:
            yield iterator.__next__()
        except StopIteration:
            iterator = iterable.__iter__()


def learning_rate_with_decay(batch_size, batch_denom, batches_per_epoch, boundary_epochs, decay_rates):
    initial_learning_rate = args.lr * batch_size / batch_denom

    boundaries = [int(batches_per_epoch * epoch) for epoch in boundary_epochs]
    vals = [initial_learning_rate * decay for decay in decay_rates]

    def learning_rate_fn(itr):
        lt = [itr < b for b in boundaries] + [True]
        i = np.argmax(lt)
        return vals[i]

    return learning_rate_fn


def one_hot(x, K):
    return np.array(x[:, None] == np.arange(K)[None, :], dtype=int)


def accuracy(model, dataset_loader):
    total_correct = 0
    for x, y in dataset_loader:
        x = x.to(device)
        y = one_hot(np.array(y.numpy()), 10)

        target_class = np.argmax(y, axis=1)
        predicted_class = np.argmax(model(x).cpu().detach().numpy(), axis=1)
        total_correct += np.sum(predicted_class == target_class)
    return total_correct / len(dataset_loader.dataset)


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


def makedirs(dirname):
    if not os.path.exists(dirname):
        os.makedirs(dirname)


def get_logger(logpath, filepath, package_files=[], displaying=True, saving=True, debug=False):
    logger = logging.getLogger()
    if debug:
        level = logging.DEBUG
    else:
        level = logging.INFO
    logger.setLevel(level)
    if saving:
        info_file_handler = logging.FileHandler(logpath, mode="a")
        info_file_handler.setLevel(level)
        logger.addHandler(info_file_handler)
    if displaying:
        console_handler = logging.StreamHandler()
        console_handler.setLevel(level)
        logger.addHandler(console_handler)
    # logger.info(filepath)
    # might not be necessary to read this file since it is raising errors anyway
    # with open(filepath, "r") as f:
        # logger.info(f.read())

    # for f in package_files:
        # logger.info(f)
        # with open(f, "r") as package_f:
            # logger.info(package_f.read())

    return logger

# %%
# This is the main function used to run the entire colab notebook
if __name__ == '__main__':

    makedirs(args.save)
    logger = get_logger(logpath=os.path.join(args.save, 'logs'), filepath=os.path.abspath('')) # adjusted for .ipynb file
    logger.info(args)

    device = torch.device('cuda:' + str(args.gpu) if torch.cuda.is_available() else 'cpu')

    # In order to plot the graphs, the data needs to be stored
    epochs = []
    train_accs = []
    test_accs = []
    epoch_times = []

    is_odenet = args.network == 'odenet'

    if args.downsampling_method == 'conv':
        downsampling_layers = [
            nn.Conv2d(1, 64, 3, 1),
            norm(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 4, 2, 1),
            norm(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 4, 2, 1),
        ]
    elif args.downsampling_method == 'res':
        downsampling_layers = [
            nn.Conv2d(1, 64, 3, 1),
            ResBlock(64, 64, stride=2, downsample=conv1x1(64, 64, 2)),
            ResBlock(64, 64, stride=2, downsample=conv1x1(64, 64, 2)),
        ]

    feature_layers = [ODEBlock(ODEfunc(64))] if is_odenet else [ResBlock(64, 64) for _ in range(6)]
    fc_layers = [norm(64), nn.ReLU(inplace=True), nn.AdaptiveAvgPool2d((1, 1)), Flatten(), nn.Linear(64, 10)]

    model = nn.Sequential(*downsampling_layers, *feature_layers, *fc_layers).to(device)

    logger.info(model)
    logger.info('Number of parameters: {}'.format(count_parameters(model)))

    criterion = nn.CrossEntropyLoss().to(device)
    train_loader, test_loader, train_eval_loader = get_mnist_loaders(
        args.data_aug, args.batch_size, args.test_batch_size
    )

    data_gen = inf_generator(train_loader)
    batches_per_epoch = len(train_loader)

    lr_fn = learning_rate_with_decay(
        args.batch_size, batch_denom=128, batches_per_epoch=batches_per_epoch, boundary_epochs=[60, 100, 140],
        decay_rates=[1, 0.1, 0.01, 0.001]
    )

    optimizer = torch.optim.SGD(model.parameters(), lr=args.lr, momentum=0.9)

    best_acc = 0
    batch_time_meter = RunningAverageMeter()
    f_nfe_meter = RunningAverageMeter()
    b_nfe_meter = RunningAverageMeter()
    end = time.time()

    for epoch in range(args.nepochs):
        start_epoch_time = time.time()

        for itr in range(batches_per_epoch):
            for param_group in optimizer.param_groups:
                param_group['lr'] = lr_fn(itr)

            optimizer.zero_grad()
            x, y = data_gen.__next__()
            x = x.to(device)
            y = y.to(device)
            logits = model(x)
            loss = criterion(logits, y)

            if is_odenet:
                nfe_forward = feature_layers[0].nfe
                feature_layers[0].nfe = 0

            loss.backward()
            optimizer.step()

            if is_odenet:
                nfe_backward = feature_layers[0].nfe
                feature_layers[0].nfe = 0

            batch_time_meter.update(time.time() - end)
            if is_odenet:
                f_nfe_meter.update(nfe_forward)
                b_nfe_meter.update(nfe_backward)
            end = time.time()

        epoch_duration = time.time() - start_epoch_time
        epoch_times.append(epoch_duration)

        with torch.no_grad():
            train_acc = accuracy(model, train_eval_loader)
            val_acc = accuracy(model, test_loader)
            if val_acc > best_acc:
                torch.save({'state_dict': model.state_dict(), 'args': args}, os.path.join(args.save, 'model.pth'))
                best_acc = val_acc

        epochs.append(epoch)
        train_accs.append(train_acc)
        test_accs.append(val_acc)

        logger.info(
            f"Epoch {epoch:04d} | Time {epoch_duration:.3f} | Train Acc {train_acc:.4f} | Test Acc {val_acc:.4f} | NFE-F {f_nfe_meter.avg:.1f} | NFE-B {b_nfe_meter.avg:.1f}"
        )
# Out:
# INFO:root:Namespace(network='odenet', tol=0.001, adjoint=False, downsampling_method='conv', nepochs=160, data_aug=True, lr=0.1, batch_size=128, test_batch_size=1000, save='./experiment1', debug=False, gpu=0)
# Namespace(network='odenet', tol=0.001, adjoint=False, downsampling_method='conv', nepochs=160, data_aug=True, lr=0.1, batch_size=128, test_batch_size=1000, save='./experiment1', debug=False, gpu=0)
# INFO:root:Sequential(
#   (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1))
#   (1): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (2): ReLU(inplace=True)
#   (3): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (4): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (5): ReLU(inplace=True)
#   (6): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (7): ODEBlock(
#     (odefunc): ODEfunc(
#       (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (relu): ReLU(inplace=True)
#       (conv1): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (conv2): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm3): GroupNorm(32, 64, eps=1e-05, affine=True)
#     )
#   )
#   (8): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (9): ReLU(inplace=True)
#   (10): AdaptiveAvgPool2d(output_size=(1, 1))
#   (11): Flatten()
#   (12): Linear(in_features=64, out_features=10, bias=True)
# )
# Sequential(
#   (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1))
#   (1): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (2): ReLU(inplace=True)
#   (3): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (4): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (5): ReLU(inplace=True)
#   (6): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (7): ODEBlock(
#     (odefunc): ODEfunc(
#       (norm1): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (relu): ReLU(inplace=True)
#       (conv1): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm2): GroupNorm(32, 64, eps=1e-05, affine=True)
#       (conv2): ConcatConv2d(
#         (_layer): Conv2d(65, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (norm3): GroupNorm(32, 64, eps=1e-05, affine=True)
#     )
#   )
#   (8): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (9): ReLU(inplace=True)
#   (10): AdaptiveAvgPool2d(output_size=(1, 1))
#   (11): Flatten()
#   (12): Linear(in_features=64, out_features=10, bias=True)
# )
# INFO:root:Number of parameters: 208266
# Number of parameters: 208266
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to .data/mnist/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:08<00:00, 1156196.94it/s]
# Extracting .data/mnist/MNIST/raw/train-images-idx3-ubyte.gz to .data/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to .data/mnist/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 134443.74it/s]
# Extracting .data/mnist/MNIST/raw/train-labels-idx1-ubyte.gz to .data/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to .data/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:06<00:00, 241721.19it/s]
# Extracting .data/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to .data/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to .data/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 9482592.72it/s]
# Extracting .data/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to .data/mnist/MNIST/raw
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# INFO:root:Epoch 0000 | Time 28.170 | Train Acc 0.9775 | Test Acc 0.9774 | NFE-F 20.1 | NFE-B 0.0
# Epoch 0000 | Time 28.170 | Train Acc 0.9775 | Test Acc 0.9774 | NFE-F 20.1 | NFE-B 0.0
# INFO:root:Epoch 0001 | Time 26.523 | Train Acc 0.9839 | Test Acc 0.9838 | NFE-F 20.2 | NFE-B 0.0
# Epoch 0001 | Time 26.523 | Train Acc 0.9839 | Test Acc 0.9838 | NFE-F 20.2 | NFE-B 0.0
# INFO:root:Epoch 0002 | Time 27.023 | Train Acc 0.9910 | Test Acc 0.9923 | NFE-F 20.4 | NFE-B 0.0
# Epoch 0002 | Time 27.023 | Train Acc 0.9910 | Test Acc 0.9923 | NFE-F 20.4 | NFE-B 0.0
# INFO:root:Epoch 0003 | Time 26.489 | Train Acc 0.9940 | Test Acc 0.9930 | NFE-F 20.1 | NFE-B 0.0
# Epoch 0003 | Time 26.489 | Train Acc 0.9940 | Test Acc 0.9930 | NFE-F 20.1 | NFE-B 0.0
# INFO:root:Epoch 0004 | Time 27.115 | Train Acc 0.9927 | Test Acc 0.9917 | NFE-F 20.6 | NFE-B 0.0
# Epoch 0004 | Time 27.115 | Train Acc 0.9927 | Test Acc 0.9917 | NFE-F 20.6 | NFE-B 0.0
# INFO:root:Epoch 0005 | Time 28.369 | Train Acc 0.9942 | Test Acc 0.9932 | NFE-F 21.2 | NFE-B 0.0
# Epoch 0005 | Time 28.369 | Train Acc 0.9942 | Test Acc 0.9932 | NFE-F 21.2 | NFE-B 0.0
# INFO:root:Epoch 0006 | Time 29.874 | Train Acc 0.9947 | Test Acc 0.9937 | NFE-F 23.1 | NFE-B 0.0
# Epoch 0006 | Time 29.874 | Train Acc 0.9947 | Test Acc 0.9937 | NFE-F 23.1 | NFE-B 0.0
# INFO:root:Epoch 0007 | Time 29.773 | Train Acc 0.9960 | Test Acc 0.9932 | NFE-F 22.3 | NFE-B 0.0
# Epoch 0007 | Time 29.773 | Train Acc 0.9960 | Test Acc 0.9932 | NFE-F 22.3 | NFE-B 0.0
# INFO:root:Epoch 0008 | Time 31.638 | Train Acc 0.9955 | Test Acc 0.9938 | NFE-F 24.0 | NFE-B 0.0
# Epoch 0008 | Time 31.638 | Train Acc 0.9955 | Test Acc 0.9938 | NFE-F 24.0 | NFE-B 0.0
# INFO:root:Epoch 0009 | Time 31.675 | Train Acc 0.9960 | Test Acc 0.9936 | NFE-F 23.6 | NFE-B 0.0
# Epoch 0009 | Time 31.675 | Train Acc 0.9960 | Test Acc 0.9936 | NFE-F 23.6 | NFE-B 0.0
# INFO:root:Epoch 0010 | Time 31.388 | Train Acc 0.9954 | Test Acc 0.9931 | NFE-F 24.6 | NFE-B 0.0
# Epoch 0010 | Time 31.388 | Train Acc 0.9954 | Test Acc 0.9931 | NFE-F 24.6 | NFE-B 0.0
# INFO:root:Epoch 0011 | Time 31.809 | Train Acc 0.9951 | Test Acc 0.9935 | NFE-F 25.6 | NFE-B 0.0
# Epoch 0011 | Time 31.809 | Train Acc 0.9951 | Test Acc 0.9935 | NFE-F 25.6 | NFE-B 0.0
| Test Acc 0.9955 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0139 | Time 33.527 | Train Acc 1.0000 | Test Acc 0.9955 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0140 | Time 33.447 | Train Acc 1.0000 | Test Acc 0.9955 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0140 | Time 33.447 | Train Acc 1.0000 | Test Acc 0.9955 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0141 | Time 33.475 | Train Acc 1.0000 | Test Acc 0.9962 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0141 | Time 33.475 | Train Acc 1.0000 | Test Acc 0.9962 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0142 | Time 33.672 | Train Acc 1.0000 | Test Acc 0.9961 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0142 | Time 33.672 | Train Acc 1.0000 | Test Acc 0.9961 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0143 | Time 33.518 | Train Acc 1.0000 | Test Acc 0.9963 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0143 | Time 33.518 | Train Acc 1.0000 | Test Acc 0.9963 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0144 | Time 33.563 | Train Acc 0.9999 | Test Acc 0.9959 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0144 | Time 33.563 | Train Acc 0.9999 | Test Acc 0.9959 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0145 | Time 33.414 | Train Acc 0.9999 | Test Acc 0.9957 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0145 | Time 33.414 | Train Acc 0.9999 | Test Acc 0.9957 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0146 | Time 33.745 | Train Acc 1.0000 | Test Acc 0.9955 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0146 | Time 33.745 | Train Acc 1.0000 | Test Acc 0.9955 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0147 | Time 33.483 | Train Acc 0.9997 | Test Acc 0.9953 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0147 | Time 33.483 | Train Acc 0.9997 | Test Acc 0.9953 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0148 | Time 33.489 | Train Acc 0.9999 | Test Acc 0.9956 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0148 | Time 33.489 | Train Acc 0.9999 | Test Acc 0.9956 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0149 | Time 33.903 | Train Acc 1.0000 | Test Acc 0.9950 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0149 | Time 33.903 | Train Acc 1.0000 | Test Acc 0.9950 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0150 | Time 33.691 | Train Acc 1.0000 | Test Acc 0.9956 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0150 | Time 33.691 | Train Acc 1.0000 | Test Acc 0.9956 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0151 | Time 33.431 | Train Acc 1.0000 | Test Acc 0.9948 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0151 | Time 33.431 | Train Acc 1.0000 | Test Acc 0.9948 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0152 | Time 33.682 | Train Acc 0.9998 | Test Acc 0.9959 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0152 | Time 33.682 | Train Acc 0.9998 | Test Acc 0.9959 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0153 | Time 33.280 | Train Acc 0.9999 | Test Acc 0.9950 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0153 | Time 33.280 | Train Acc 0.9999 | Test Acc 0.9950 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0154 | Time 33.535 | Train Acc 1.0000 | Test Acc 0.9956 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0154 | Time 33.535 | Train Acc 1.0000 | Test Acc 0.9956 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0155 | Time 33.431 | Train Acc 0.9999 | Test Acc 0.9952 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0155 | Time 33.431 | Train Acc 0.9999 | Test Acc 0.9952 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0156 | Time 33.608 | Train Acc 1.0000 | Test Acc 0.9949 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0156 | Time 33.608 | Train Acc 1.0000 | Test Acc 0.9949 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0157 | Time 33.509 | Train Acc 1.0000 | Test Acc 0.9957 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0157 | Time 33.509 | Train Acc 1.0000 | Test Acc 0.9957 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0158 | Time 33.327 | Train Acc 1.0000 | Test Acc 0.9962 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0158 | Time 33.327 | Train Acc 1.0000 | Test Acc 0.9962 | NFE-F 26.2 | NFE-B 0.0
# INFO:root:Epoch 0159 | Time 33.435 | Train Acc 1.0000 | Test Acc 0.9960 | NFE-F 26.2 | NFE-B 0.0
# Epoch 0159 | Time 33.435 | Train Acc 1.0000 | Test Acc 0.9960 | NFE-F 26.2 | NFE-B 0.0

# %%
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_accs, label='Train Accuracy')
plt.plot(epochs, test_accs, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Epoch vs Accuracy')
plt.legend()
plt.grid(True)
plt.show()

average_epoch_time = sum(epoch_times) / len(epoch_times)
print(f"Average Wall-Clock Time per Epoch: {average_epoch_time:.3f} seconds")
# Out:
# Average Wall-Clock Time per Epoch: 33.063 seconds
